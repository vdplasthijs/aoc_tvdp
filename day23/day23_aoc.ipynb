# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import os, sys 
sys.path.append('..')
import collections
import copy
import itertools
import aoc_utils as au
import math 
from tqdm import tqdm

# %%
input_text = au.read_txt_file_lines('input.txt')
n_rows = len(input_text)
n_cols = len(input_text[0])
for ii in range(1, n_rows):
    assert len(input_text[ii]) == n_cols, f'row {ii} has {len(input_text[ii])} cols, not {n_cols}'
print(f'input has {n_rows} rows and {n_cols} cols')

for ic, col in enumerate(input_text[0]):
    if ic != 1:
        assert col == '#', ic
for ic, col in enumerate(input_text[-1]):
    if ic != n_cols - 2:
        assert col == '#', ic
for row in input_text:
    assert row[0] == '#', f'row {row} not valid'
    assert row[-1] == '#', f'row {row} not valid'

unique_chars = set()
for row in input_text:
    unique_chars.update(row)
print(f'unique_chars: {unique_chars}')
# Out:
# input has 141 rows and 141 cols
# unique_chars: {'v', '.', '#', '>'}

# %%
path_tuple = collections.namedtuple('path', 'head visited_nodes')

def progress_til_junction(path, input_text, end_node=(n_rows - 1, n_cols - 2)):
    n_rows, n_cols = len(input_text), len(input_text[0])
    current_row, current_col = path.head
    while True:
        possible_next_nodes = []
        if input_text[current_row][current_col] == '>':
            if current_col < n_cols - 1 and input_text[current_row][current_col + 1] in ['.', '>']:
                possible_next_nodes.append((current_row, current_col + 1))
        elif input_text[current_row][current_col] == 'v':
            if current_row < n_rows - 1 and input_text[current_row + 1][current_col] in ['.', 'v']:
                possible_next_nodes.append((current_row + 1, current_col))
        else:
            if current_col < n_cols - 1 and input_text[current_row][current_col + 1] in ['.', '>']:
                possible_next_nodes.append((current_row, current_col + 1))
            if current_col > 0 and input_text[current_row][current_col - 1] == '.':
                possible_next_nodes.append((current_row, current_col - 1))
            if current_row < n_rows - 1 and input_text[current_row + 1][current_col] in ['.', 'v']:
                possible_next_nodes.append((current_row + 1, current_col))
            if current_row > 0 and input_text[current_row - 1][current_col] == '.':
                possible_next_nodes.append((current_row - 1, current_col))

        possible_next_nodes = [node for node in possible_next_nodes if node not in path.visited_nodes]

        if len(possible_next_nodes) == 0:
            if path.head == end_node:
                return True, path
            else:
                print(f'path {path} has no possible next nodes')
                return False, []
        elif len(possible_next_nodes) == 1:
            new_visited_nodes = copy.deepcopy(path.visited_nodes)
            new_visited_nodes.add(path.head)
            path = path._replace(head=possible_next_nodes[0])
            path = path._replace(visited_nodes=new_visited_nodes)
            current_row, current_col = path.head
        else:
            new_paths = []
            for node in possible_next_nodes:
                new_visited_nodes = copy.deepcopy(path.visited_nodes)
                new_visited_nodes.add(path.head)
                new_paths.append(path_tuple(node, new_visited_nodes))
            return False, new_paths 
        
def find_longest_path(input_text, start_row=0, start_col=1, verbose=1):
    visited_nodes = set()
    visited_nodes.add((start_row, start_col))
    queue_paths = collections.deque()
    queue_paths.append(path_tuple((start_row, start_col), visited_nodes))
    paths_to_end = []
    i_path = 0
    while len(queue_paths) > 0: 
        i_path += 1
        current_path = queue_paths.popleft()
        if verbose > 0:
            print(f'starting new path (#{i_path}), starting at {current_path.head}. {len(queue_paths)} paths left in queue')
        reached_end, new_path = progress_til_junction(current_path, input_text)
        if reached_end:
            if  verbose > 1:
                print(f'found end {new_path}')
            paths_to_end.append(new_path)
        else:
            if verbose > 1:
                print(f'adding {len(new_path)} new paths')
            queue_paths.extend(new_path)

    if verbose > 0:
        print(f'found {len(paths_to_end)} paths to end')
    return paths_to_end

# %%
paths_to_end = find_longest_path(input_text, verbose=1)
paths_length = [len(path.visited_nodes) for path in paths_to_end]
max_path_length = max(paths_length)
print(f'max_path_length: {max_path_length}')
# Out:
# starting new path (#1), starting at (0, 1). 0 paths left in queue
# starting new path (#2), starting at (17, 20). 1 paths left in queue
# starting new path (#3), starting at (18, 19). 2 paths left in queue
# starting new path (#4), starting at (9, 30). 3 paths left in queue
# starting new path (#5), starting at (10, 29). 4 paths left in queue
# starting new path (#6), starting at (37, 14). 5 paths left in queue
# starting new path (#7), starting at (38, 13). 6 paths left in queue
# starting new path (#8), starting at (11, 62). 7 paths left in queue
# starting new path (#9), starting at (12, 61). 8 paths left in queue
# starting new path (#10), starting at (43, 42). 9 paths left in queue
# starting new path (#11), starting at (44, 41). 10 paths left in queue
# starting new path (#12), starting at (43, 42). 11 paths left in queue
# starting new path (#13), starting at (44, 41). 12 paths left in queue
# starting new path (#14), starting at (53, 18). 13 paths left in queue
# starting new path (#15), starting at (54, 17). 14 paths left in queue
# starting new path (#16), starting at (13, 86). 15 paths left in queue
# starting new path (#17), starting at (14, 85). 16 paths left in queue
# starting new path (#18), starting at (41, 64). 17 paths left in queue
# starting new path (#19), starting at (42, 63). 18 paths left in queue
# starting new path (#20), starting at (41, 64). 19 paths left in queue
# starting new path (#21), starting at (42, 63). 20 paths left in queue
# starting new path (#22), starting at (61, 38). 21 paths left in queue
# starting new path (#23), starting at (62, 37). 22 paths left in queue
# starting new path (#24), starting at (41, 64). 23 paths left in queue
# starting new path (#25), starting at (42, 63). 24 paths left in queue
# starting new path (#26), starting at (61, 38). 25 paths left in queue
# starting new path (#27), starting at (62, 37). 26 paths left in queue
# starting new path (#28), starting at (61, 38). 27 paths left in queue
# starting new path (#29), starting at (62, 37). 28 paths left in queue
# starting new path (#30), starting at (77, 18). 29 paths left in queue
# starting new path (#31), starting at (78, 17). 30 paths left in queue
# starting new path (#32), starting at (7, 106). 31 paths left in queue
# starting new path (#33), starting at (8, 105). 30 paths left in queue
# starting new path (#34), starting at (41, 80). 31 paths left in queue
# starting new path (#35), starting at (42, 79). 32 paths left in queue
# starting new path (#36), starting at (41, 80). 33 paths left in queue
# starting new path (#37), starting at (42, 79). 34 paths left in queue
# starting new path (#38), starting at (65, 56). 35 paths left in queue
# starting new path (#39), starting at (66, 55). 36 paths left in queue
# starting new path (#40), starting at (41, 80). 37 paths left in queue
# starting new path (#41), starting at (42, 79). 38 paths left in queue
# starting new path (#42), starting at (65, 56). 39 paths left in queue
# starting new path (#43), starting at (66, 55). 40 paths left in queue
# starting new path (#44), starting at (65, 56). 41 paths left in queue
# starting new path (#45), starting at (66, 55). 42 paths left in queue
# starting new path (#46), starting at (87, 40). 43 paths left in queue
# starting new path (#47), starting at (88, 39). 44 paths left in queue
# starting new path (#48), starting at (41, 80). 45 paths left in queue
# starting new path (#49), starting at (42, 79). 46 paths left in queue
# starting new path (#50), starting at (65, 56). 47 paths left in queue
# starting new path (#51), starting at (66, 55). 48 paths left in queue
# starting new path (#52), starting at (65, 56). 49 paths left in queue
# starting new path (#53), starting at (66, 55). 50 paths left in queue
# starting new path (#54), starting at (87, 40). 51 paths left in queue
# starting new path (#55), starting at (88, 39). 52 paths left in queue
# starting new path (#56), starting at (65, 56). 53 paths left in queue
# starting new path (#57), starting at (66, 55). 54 paths left in queue
# starting new path (#58), starting at (87, 40). 55 paths left in queue
# starting new path (#59), starting at (88, 39). 56 paths left in queue
# starting new path (#60), starting at (87, 40). 57 paths left in queue
# starting new path (#61), starting at (88, 39). 58 paths left in queue
# starting new path (#62), starting at (107, 14). 59 paths left in queue
# starting new path (#63), starting at (108, 13). 60 paths left in queue
# starting new path (#64), starting at (35, 100). 59 paths left in queue
# starting new path (#65), starting at (36, 99). 58 paths left in queue
# starting new path (#66), starting at (35, 100). 59 paths left in queue
# starting new path (#67), starting at (36, 99). 58 paths left in queue
# starting new path (#68), starting at (63, 84). 59 paths left in queue
# starting new path (#69), starting at (64, 83). 60 paths left in queue
# starting new path (#70), starting at (35, 100). 61 paths left in queue
# starting new path (#71), starting at (36, 99). 60 paths left in queue
# starting new path (#72), starting at (63, 84). 61 paths left in queue
# starting new path (#73), starting at (64, 83). 62 paths left in queue
# starting new path (#74), starting at (63, 84). 63 paths left in queue
# starting new path (#75), starting at (64, 83). 64 paths left in queue
# starting new path (#76), starting at (89, 56). 65 paths left in queue
# starting new path (#77), starting at (90, 55). 66 paths left in queue
# starting new path (#78), starting at (35, 100). 67 paths left in queue
# starting new path (#79), starting at (36, 99). 66 paths left in queue
# starting new path (#80), starting at (63, 84). 67 paths left in queue
# starting new path (#81), starting at (64, 83). 68 paths left in queue
# starting new path (#82), starting at (63, 84). 69 paths left in queue
# starting new path (#83), starting at (64, 83). 70 paths left in queue
# starting new path (#84), starting at (89, 56). 71 paths left in queue
# starting new path (#85), starting at (90, 55). 72 paths left in queue
# starting new path (#86), starting at (63, 84). 73 paths left in queue
# starting new path (#87), starting at (64, 83). 74 paths left in queue
# starting new path (#88), starting at (89, 56). 75 paths left in queue
# starting new path (#89), starting at (90, 55). 76 paths left in queue
# starting new path (#90), starting at (89, 56). 77 paths left in queue
# starting new path (#91), starting at (90, 55). 78 paths left in queue
# starting new path (#92), starting at (99, 32). 79 paths left in queue
# starting new path (#93), starting at (100, 31). 80 paths left in queue
# starting new path (#94), starting at (35, 100). 79 paths left in queue
# starting new path (#95), starting at (36, 99). 78 paths left in queue
# starting new path (#96), starting at (63, 84). 79 paths left in queue
# starting new path (#97), starting at (64, 83). 80 paths left in queue
# starting new path (#98), starting at (63, 84). 81 paths left in queue
# starting new path (#99), starting at (64, 83). 82 paths left in queue
# starting new path (#100), starting at (89, 56). 83 paths left in queue
# starting new path (#101), starting at (90, 55). 84 paths left in queue
# starting new path (#102), starting at (63, 84). 85 paths left in queue
# starting new path (#103), starting at (64, 83). 86 paths left in queue
# starting new path (#104), starting at (89, 56). 87 paths left in queue
# starting new path (#105), starting at (90, 55). 88 paths left in queue
# starting new path (#106), starting at (89, 56). 89 paths left in queue
# starting new path (#107), starting at (90, 55). 90 paths left in queue
# starting new path (#108), starting at (99, 32). 91 paths left in queue
# starting new path (#109), starting at (100, 31). 92 paths left in queue
# starting new path (#110), starting at (63, 84). 91 paths left in queue
# starting new path (#111), starting at (64, 83). 92 paths left in queue
# starting new path (#112), starting at (89, 56). 93 paths left in queue
# starting new path (#113), starting at (90, 55). 94 paths left in queue
# starting new path (#114), starting at (89, 56). 95 paths left in queue
# starting new path (#115), starting at (90, 55). 96 paths left in queue
# starting new path (#116), starting at (99, 32). 97 paths left in queue
# starting new path (#117), starting at (100, 31). 98 paths left in queue
# starting new path (#118), starting at (89, 56). 97 paths left in queue
# starting new path (#119), starting at (90, 55). 98 paths left in queue
# starting new path (#120), starting at (99, 32). 99 paths left in queue
# starting new path (#121), starting at (100, 31). 100 paths left in queue
# starting new path (#122), starting at (99, 32). 99 paths left in queue
# starting new path (#123), starting at (100, 31). 100 paths left in queue
# starting new path (#124), starting at (53, 110). 99 paths left in queue
# starting new path (#125), starting at (54, 109). 98 paths left in queue
# starting new path (#126), starting at (53, 110). 99 paths left in queue
# starting new path (#127), starting at (54, 109). 98 paths left in queue
# starting new path (#128), starting at (53, 110). 99 paths left in queue
# starting new path (#129), starting at (54, 109). 98 paths left in queue
# starting new path (#130), starting at (77, 86). 99 paths left in queue
# starting new path (#131), starting at (78, 85). 100 paths left in queue
# starting new path (#132), starting at (53, 110). 101 paths left in queue
# starting new path (#133), starting at (54, 109). 100 paths left in queue
# starting new path (#134), starting at (53, 110). 101 paths left in queue
# starting new path (#135), starting at (54, 109). 100 paths left in queue
# starting new path (#136), starting at (77, 86). 101 paths left in queue
# starting new path (#137), starting at (78, 85). 102 paths left in queue
# starting new path (#138), starting at (53, 110). 103 paths left in queue
# starting new path (#139), starting at (54, 109). 102 paths left in queue
# starting new path (#140), starting at (77, 86). 103 paths left in queue
# starting new path (#141), starting at (78, 85). 104 paths left in queue
# starting new path (#142), starting at (77, 86). 105 paths left in queue
# starting new path (#143), starting at (78, 85). 106 paths left in queue
# starting new path (#144), starting at (113, 68). 107 paths left in queue
# starting new path (#145), starting at (114, 67). 108 paths left in queue
# starting new path (#146), starting at (53, 110). 107 paths left in queue
# starting new path (#147), starting at (54, 109). 106 paths left in queue
# starting new path (#148), starting at (53, 110). 107 paths left in queue
# starting new path (#149), starting at (54, 109). 106 paths left in queue
# starting new path (#150), starting at (77, 86). 107 paths left in queue
# starting new path (#151), starting at (78, 85). 108 paths left in queue
# starting new path (#152), starting at (53, 110). 109 paths left in queue
# starting new path (#153), starting at (54, 109). 108 paths left in queue
# starting new path (#154), starting at (77, 86). 109 paths left in queue
# starting new path (#155), starting at (78, 85). 110 paths left in queue
# starting new path (#156), starting at (77, 86). 111 paths left in queue
# starting new path (#157), starting at (78, 85). 112 paths left in queue
# starting new path (#158), starting at (113, 68). 113 paths left in queue
# starting new path (#159), starting at (114, 67). 114 paths left in queue
# starting new path (#160), starting at (53, 110). 113 paths left in queue
# starting new path (#161), starting at (54, 109). 112 paths left in queue
# starting new path (#162), starting at (77, 86). 113 paths left in queue
# starting new path (#163), starting at (78, 85). 114 paths left in queue
# starting new path (#164), starting at (77, 86). 115 paths left in queue
# starting new path (#165), starting at (78, 85). 116 paths left in queue
# starting new path (#166), starting at (113, 68). 117 paths left in queue
# starting new path (#167), starting at (114, 67). 118 paths left in queue
# starting new path (#168), starting at (77, 86). 117 paths left in queue
# starting new path (#169), starting at (78, 85). 118 paths left in queue
# starting new path (#170), starting at (113, 68). 119 paths left in queue
# starting new path (#171), starting at (114, 67). 120 paths left in queue
# starting new path (#172), starting at (113, 68). 119 paths left in queue
# starting new path (#173), starting at (114, 67). 120 paths left in queue
# starting new path (#174), starting at (53, 110). 119 paths left in queue
# starting new path (#175), starting at (54, 109). 118 paths left in queue
# starting new path (#176), starting at (53, 110). 119 paths left in queue
# starting new path (#177), starting at (54, 109). 118 paths left in queue
# starting new path (#178), starting at (77, 86). 119 paths left in queue
# starting new path (#179), starting at (78, 85). 120 paths left in queue
# starting new path (#180), starting at (53, 110). 121 paths left in queue
# starting new path (#181), starting at (54, 109). 120 paths left in queue
# starting new path (#182), starting at (77, 86). 121 paths left in queue
# starting new path (#183), starting at (78, 85). 122 paths left in queue
# starting new path (#184), starting at (77, 86). 123 paths left in queue
# starting new path (#185), starting at (78, 85). 124 paths left in queue
# starting new path (#186), starting at (113, 68). 125 paths left in queue
# starting new path (#187), starting at (114, 67). 126 paths left in queue
# starting new path (#188), starting at (53, 110). 125 paths left in queue
# starting new path (#189), starting at (54, 109). 124 paths left in queue
# starting new path (#190), starting at (77, 86). 125 paths left in queue
# starting new path (#191), starting at (78, 85). 126 paths left in queue
# starting new path (#192), starting at (77, 86). 127 paths left in queue
# starting new path (#193), starting at (78, 85). 128 paths left in queue
# starting new path (#194), starting at (113, 68). 129 paths left in queue
# starting new path (#195), starting at (114, 67). 130 paths left in queue
# starting new path (#196), starting at (77, 86). 129 paths left in queue
# starting new path (#197), starting at (78, 85). 130 paths left in queue
# starting new path (#198), starting at (113, 68). 131 paths left in queue
# starting new path (#199), starting at (114, 67). 132 paths left in queue
# starting new path (#200), starting at (113, 68). 131 paths left in queue
# starting new path (#201), starting at (114, 67). 132 paths left in queue
# starting new path (#202), starting at (53, 110). 131 paths left in queue
# starting new path (#203), starting at (54, 109). 130 paths left in queue
# starting new path (#204), starting at (77, 86). 131 paths left in queue
# starting new path (#205), starting at (78, 85). 132 paths left in queue
# starting new path (#206), starting at (77, 86). 133 paths left in queue
# starting new path (#207), starting at (78, 85). 134 paths left in queue
# starting new path (#208), starting at (113, 68). 135 paths left in queue
# starting new path (#209), starting at (114, 67). 136 paths left in queue
# starting new path (#210), starting at (77, 86). 135 paths left in queue
# starting new path (#211), starting at (78, 85). 136 paths left in queue
# starting new path (#212), starting at (113, 68). 137 paths left in queue
# starting new path (#213), starting at (114, 67). 138 paths left in queue
# starting new path (#214), starting at (113, 68). 137 paths left in queue
# starting new path (#215), starting at (114, 67). 138 paths left in queue
# starting new path (#216), starting at (77, 86). 137 paths left in queue
# starting new path (#217), starting at (78, 85). 138 paths left in queue
# starting new path (#218), starting at (113, 68). 139 paths left in queue
# starting new path (#219), starting at (114, 67). 140 paths left in queue
# starting new path (#220), starting at (113, 68). 139 paths left in queue
# starting new path (#221), starting at (114, 67). 140 paths left in queue
# starting new path (#222), starting at (113, 68). 139 paths left in queue
# starting new path (#223), starting at (114, 67). 140 paths left in queue
# starting new path (#224), starting at (75, 108). 139 paths left in queue
# starting new path (#225), starting at (76, 107). 138 paths left in queue
# starting new path (#226), starting at (75, 108). 139 paths left in queue
# starting new path (#227), starting at (76, 107). 138 paths left in queue
# starting new path (#228), starting at (75, 108). 139 paths left in queue
# starting new path (#229), starting at (76, 107). 138 paths left in queue
# starting new path (#230), starting at (75, 108). 139 paths left in queue
# starting new path (#231), starting at (76, 107). 138 paths left in queue
# starting new path (#232), starting at (101, 78). 139 paths left in queue
# starting new path (#233), starting at (102, 77). 140 paths left in queue
# starting new path (#234), starting at (75, 108). 139 paths left in queue
# starting new path (#235), starting at (76, 107). 138 paths left in queue
# starting new path (#236), starting at (75, 108). 139 paths left in queue
# starting new path (#237), starting at (76, 107). 138 paths left in queue
# starting new path (#238), starting at (75, 108). 139 paths left in queue
# starting new path (#239), starting at (76, 107). 138 paths left in queue
# starting new path (#240), starting at (101, 78). 139 paths left in queue
# starting new path (#241), starting at (102, 77). 140 paths left in queue
# starting new path (#242), starting at (75, 108). 139 paths left in queue
# starting new path (#243), starting at (76, 107). 138 paths left in queue
# starting new path (#244), starting at (75, 108). 139 paths left in queue
# starting new path (#245), starting at (76, 107). 138 paths left in queue
# starting new path (#246), starting at (101, 78). 139 paths left in queue
# starting new path (#247), starting at (102, 77). 140 paths left in queue
# starting new path (#248), starting at (75, 108). 139 paths left in queue
# starting new path (#249), starting at (76, 107). 138 paths left in queue
# starting new path (#250), starting at (101, 78). 139 paths left in queue
# starting new path (#251), starting at (102, 77). 140 paths left in queue
# starting new path (#252), starting at (101, 78). 139 paths left in queue
# starting new path (#253), starting at (102, 77). 140 paths left in queue
# starting new path (#254), starting at (75, 108). 139 paths left in queue
# starting new path (#255), starting at (76, 107). 138 paths left in queue
# starting new path (#256), starting at (75, 108). 139 paths left in queue
# starting new path (#257), starting at (76, 107). 138 paths left in queue
# starting new path (#258), starting at (75, 108). 139 paths left in queue
# starting new path (#259), starting at (76, 107). 138 paths left in queue
# starting new path (#260), starting at (101, 78). 139 paths left in queue
# starting new path (#261), starting at (102, 77). 140 paths left in queue
# starting new path (#262), starting at (75, 108). 139 paths left in queue
# starting new path (#263), starting at (76, 107). 138 paths left in queue
# starting new path (#264), starting at (75, 108). 139 paths left in queue
# starting new path (#265), starting at (76, 107). 138 paths left in queue
# starting new path (#266), starting at (101, 78). 139 paths left in queue
# starting new path (#267), starting at (102, 77). 140 paths left in queue
# starting new path (#268), starting at (75, 108). 139 paths left in queue
# starting new path (#269), starting at (76, 107). 138 paths left in queue
# starting new path (#270), starting at (101, 78). 139 paths left in queue
# starting new path (#271), starting at (102, 77). 140 paths left in queue
# starting new path (#272), starting at (101, 78). 139 paths left in queue
# starting new path (#273), starting at (102, 77). 140 paths left in queue
# starting new path (#274), starting at (75, 108). 139 paths left in queue
# starting new path (#275), starting at (76, 107). 138 paths left in queue
# starting new path (#276), starting at (75, 108). 139 paths left in queue
# starting new path (#277), starting at (76, 107). 138 paths left in queue
# starting new path (#278), starting at (101, 78). 139 paths left in queue
# starting new path (#279), starting at (102, 77). 140 paths left in queue
# starting new path (#280), starting at (75, 108). 139 paths left in queue
# starting new path (#281), starting at (76, 107). 138 paths left in queue
# starting new path (#282), starting at (101, 78). 139 paths left in queue
# starting new path (#283), starting at (102, 77). 140 paths left in queue
# starting new path (#284), starting at (101, 78). 139 paths left in queue
# starting new path (#285), starting at (102, 77). 140 paths left in queue
# starting new path (#286), starting at (75, 108). 139 paths left in queue
# starting new path (#287), starting at (76, 107). 138 paths left in queue
# starting new path (#288), starting at (101, 78). 139 paths left in queue
# starting new path (#289), starting at (102, 77). 140 paths left in queue
# starting new path (#290), starting at (101, 78). 139 paths left in queue
# starting new path (#291), starting at (102, 77). 140 paths left in queue
# starting new path (#292), starting at (101, 78). 139 paths left in queue
# starting new path (#293), starting at (102, 77). 140 paths left in queue
# starting new path (#294), starting at (75, 108). 139 paths left in queue
# starting new path (#295), starting at (76, 107). 138 paths left in queue
# starting new path (#296), starting at (75, 108). 139 paths left in queue
# starting new path (#297), starting at (76, 107). 138 paths left in queue
# starting new path (#298), starting at (75, 108). 139 paths left in queue
# starting new path (#299), starting at (76, 107). 138 paths left in queue
# starting new path (#300), starting at (101, 78). 139 paths left in queue
# starting new path (#301), starting at (102, 77). 140 paths left in queue
# starting new path (#302), starting at (75, 108). 139 paths left in queue
# starting new path (#303), starting at (76, 107). 138 paths left in queue
# starting new path (#304), starting at (75, 108). 139 paths left in queue
# starting new path (#305), starting at (76, 107). 138 paths left in queue
# starting new path (#306), starting at (101, 78). 139 paths left in queue
# starting new path (#307), starting at (102, 77). 140 paths left in queue
# starting new path (#308), starting at (75, 108). 139 paths left in queue
# starting new path (#309), starting at (76, 107). 138 paths left in queue
# starting new path (#310), starting at (101, 78). 139 paths left in queue
# starting new path (#311), starting at (102, 77). 140 paths left in queue
# starting new path (#312), starting at (101, 78). 139 paths left in queue
# starting new path (#313), starting at (102, 77). 140 paths left in queue
# starting new path (#314), starting at (75, 108). 139 paths left in queue
# starting new path (#315), starting at (76, 107). 138 paths left in queue
# starting new path (#316), starting at (75, 108). 139 paths left in queue
# starting new path (#317), starting at (76, 107). 138 paths left in queue
# starting new path (#318), starting at (101, 78). 139 paths left in queue
# starting new path (#319), starting at (102, 77). 140 paths left in queue
# starting new path (#320), starting at (75, 108). 139 paths left in queue
# starting new path (#321), starting at (76, 107). 138 paths left in queue
# starting new path (#322), starting at (101, 78). 139 paths left in queue
# starting new path (#323), starting at (102, 77). 140 paths left in queue
# starting new path (#324), starting at (101, 78). 139 paths left in queue
# starting new path (#325), starting at (102, 77). 140 paths left in queue
# starting new path (#326), starting at (75, 108). 139 paths left in queue
# starting new path (#327), starting at (76, 107). 138 paths left in queue
# starting new path (#328), starting at (101, 78). 139 paths left in queue
# starting new path (#329), starting at (102, 77). 140 paths left in queue
# starting new path (#330), starting at (101, 78). 139 paths left in queue
# starting new path (#331), starting at (102, 77). 140 paths left in queue
# starting new path (#332), starting at (101, 78). 139 paths left in queue
# starting new path (#333), starting at (102, 77). 140 paths left in queue
# starting new path (#334), starting at (75, 108). 139 paths left in queue
# starting new path (#335), starting at (76, 107). 138 paths left in queue
# starting new path (#336), starting at (75, 108). 139 paths left in queue
# starting new path (#337), starting at (76, 107). 138 paths left in queue
# starting new path (#338), starting at (101, 78). 139 paths left in queue
# starting new path (#339), starting at (102, 77). 140 paths left in queue
# starting new path (#340), starting at (75, 108). 139 paths left in queue
# starting new path (#341), starting at (76, 107). 138 paths left in queue
# starting new path (#342), starting at (101, 78). 139 paths left in queue
# starting new path (#343), starting at (102, 77). 140 paths left in queue
# starting new path (#344), starting at (101, 78). 139 paths left in queue
# starting new path (#345), starting at (102, 77). 140 paths left in queue
# starting new path (#346), starting at (75, 108). 139 paths left in queue
# starting new path (#347), starting at (76, 107). 138 paths left in queue
# starting new path (#348), starting at (101, 78). 139 paths left in queue
# starting new path (#349), starting at (102, 77). 140 paths left in queue
# starting new path (#350), starting at (101, 78). 139 paths left in queue
# starting new path (#351), starting at (102, 77). 140 paths left in queue
# starting new path (#352), starting at (101, 78). 139 paths left in queue
# starting new path (#353), starting at (102, 77). 140 paths left in queue
# starting new path (#354), starting at (75, 108). 139 paths left in queue
# starting new path (#355), starting at (76, 107). 138 paths left in queue
# starting new path (#356), starting at (101, 78). 139 paths left in queue
# starting new path (#357), starting at (102, 77). 140 paths left in queue
# starting new path (#358), starting at (101, 78). 139 paths left in queue
# starting new path (#359), starting at (102, 77). 140 paths left in queue
# starting new path (#360), starting at (101, 78). 139 paths left in queue
# starting new path (#361), starting at (102, 77). 140 paths left in queue
# starting new path (#362), starting at (101, 78). 139 paths left in queue
# starting new path (#363), starting at (102, 77). 140 paths left in queue
# starting new path (#364), starting at (107, 112). 139 paths left in queue
# starting new path (#365), starting at (108, 111). 138 paths left in queue
# starting new path (#366), starting at (107, 112). 137 paths left in queue
# starting new path (#367), starting at (108, 111). 136 paths left in queue
# starting new path (#368), starting at (107, 112). 135 paths left in queue
# starting new path (#369), starting at (108, 111). 134 paths left in queue
# starting new path (#370), starting at (107, 112). 133 paths left in queue
# starting new path (#371), starting at (108, 111). 132 paths left in queue
# starting new path (#372), starting at (107, 112). 131 paths left in queue
# starting new path (#373), starting at (108, 111). 130 paths left in queue
# starting new path (#374), starting at (107, 112). 129 paths left in queue
# starting new path (#375), starting at (108, 111). 128 paths left in queue
# starting new path (#376), starting at (107, 112). 127 paths left in queue
# starting new path (#377), starting at (108, 111). 126 paths left in queue
# starting new path (#378), starting at (107, 112). 125 paths left in queue
# starting new path (#379), starting at (108, 111). 124 paths left in queue
# starting new path (#380), starting at (107, 112). 123 paths left in queue
# starting new path (#381), starting at (108, 111). 122 paths left in queue
# starting new path (#382), starting at (107, 112). 121 paths left in queue
# starting new path (#383), starting at (108, 111). 120 paths left in queue
# starting new path (#384), starting at (107, 112). 119 paths left in queue
# starting new path (#385), starting at (108, 111). 118 paths left in queue
# starting new path (#386), starting at (107, 112). 117 paths left in queue
# starting new path (#387), starting at (108, 111). 116 paths left in queue
# starting new path (#388), starting at (107, 112). 115 paths left in queue
# starting new path (#389), starting at (108, 111). 114 paths left in queue
# starting new path (#390), starting at (107, 112). 113 paths left in queue
# starting new path (#391), starting at (108, 111). 112 paths left in queue
# starting new path (#392), starting at (107, 112). 111 paths left in queue
# starting new path (#393), starting at (108, 111). 110 paths left in queue
# starting new path (#394), starting at (107, 112). 109 paths left in queue
# starting new path (#395), starting at (108, 111). 108 paths left in queue
# starting new path (#396), starting at (107, 112). 107 paths left in queue
# starting new path (#397), starting at (108, 111). 106 paths left in queue
# starting new path (#398), starting at (107, 112). 105 paths left in queue
# starting new path (#399), starting at (108, 111). 104 paths left in queue
# starting new path (#400), starting at (107, 112). 103 paths left in queue
# starting new path (#401), starting at (108, 111). 102 paths left in queue
# starting new path (#402), starting at (107, 112). 101 paths left in queue
# starting new path (#403), starting at (108, 111). 100 paths left in queue
# starting new path (#404), starting at (107, 112). 99 paths left in queue
# starting new path (#405), starting at (108, 111). 98 paths left in queue
# starting new path (#406), starting at (107, 112). 97 paths left in queue
# starting new path (#407), starting at (108, 111). 96 paths left in queue
# starting new path (#408), starting at (107, 112). 95 paths left in queue
# starting new path (#409), starting at (108, 111). 94 paths left in queue
# starting new path (#410), starting at (107, 112). 93 paths left in queue
# starting new path (#411), starting at (108, 111). 92 paths left in queue
# starting new path (#412), starting at (107, 112). 91 paths left in queue
# starting new path (#413), starting at (108, 111). 90 paths left in queue
# starting new path (#414), starting at (107, 112). 89 paths left in queue
# starting new path (#415), starting at (108, 111). 88 paths left in queue
# starting new path (#416), starting at (107, 112). 87 paths left in queue
# starting new path (#417), starting at (108, 111). 86 paths left in queue
# starting new path (#418), starting at (107, 112). 85 paths left in queue
# starting new path (#419), starting at (108, 111). 84 paths left in queue
# starting new path (#420), starting at (107, 112). 83 paths left in queue
# starting new path (#421), starting at (108, 111). 82 paths left in queue
# starting new path (#422), starting at (107, 112). 81 paths left in queue
# starting new path (#423), starting at (108, 111). 80 paths left in queue
# starting new path (#424), starting at (107, 112). 79 paths left in queue
# starting new path (#425), starting at (108, 111). 78 paths left in queue
# starting new path (#426), starting at (107, 112). 77 paths left in queue
# starting new path (#427), starting at (108, 111). 76 paths left in queue
# starting new path (#428), starting at (107, 112). 75 paths left in queue
# starting new path (#429), starting at (108, 111). 74 paths left in queue
# starting new path (#430), starting at (107, 112). 73 paths left in queue
# starting new path (#431), starting at (108, 111). 72 paths left in queue
# starting new path (#432), starting at (107, 112). 71 paths left in queue
# starting new path (#433), starting at (108, 111). 70 paths left in queue
# starting new path (#434), starting at (107, 112). 69 paths left in queue
# starting new path (#435), starting at (108, 111). 68 paths left in queue
# starting new path (#436), starting at (107, 112). 67 paths left in queue
# starting new path (#437), starting at (108, 111). 66 paths left in queue
# starting new path (#438), starting at (107, 112). 65 paths left in queue
# starting new path (#439), starting at (108, 111). 64 paths left in queue
# starting new path (#440), starting at (107, 112). 63 paths left in queue
# starting new path (#441), starting at (108, 111). 62 paths left in queue
# starting new path (#442), starting at (107, 112). 61 paths left in queue
# starting new path (#443), starting at (108, 111). 60 paths left in queue
# starting new path (#444), starting at (107, 112). 59 paths left in queue
# starting new path (#445), starting at (108, 111). 58 paths left in queue
# starting new path (#446), starting at (107, 112). 57 paths left in queue
# starting new path (#447), starting at (108, 111). 56 paths left in queue
# starting new path (#448), starting at (107, 112). 55 paths left in queue
# starting new path (#449), starting at (108, 111). 54 paths left in queue
# starting new path (#450), starting at (107, 112). 53 paths left in queue
# starting new path (#451), starting at (108, 111). 52 paths left in queue
# starting new path (#452), starting at (107, 112). 51 paths left in queue
# starting new path (#453), starting at (108, 111). 50 paths left in queue
# starting new path (#454), starting at (107, 112). 49 paths left in queue
# starting new path (#455), starting at (108, 111). 48 paths left in queue
# starting new path (#456), starting at (107, 112). 47 paths left in queue
# starting new path (#457), starting at (108, 111). 46 paths left in queue
# starting new path (#458), starting at (107, 112). 45 paths left in queue
# starting new path (#459), starting at (108, 111). 44 paths left in queue
# starting new path (#460), starting at (107, 112). 43 paths left in queue
# starting new path (#461), starting at (108, 111). 42 paths left in queue
# starting new path (#462), starting at (107, 112). 41 paths left in queue
# starting new path (#463), starting at (108, 111). 40 paths left in queue
# starting new path (#464), starting at (107, 112). 39 paths left in queue
# starting new path (#465), starting at (108, 111). 38 paths left in queue
# starting new path (#466), starting at (107, 112). 37 paths left in queue
# starting new path (#467), starting at (108, 111). 36 paths left in queue
# starting new path (#468), starting at (107, 112). 35 paths left in queue
# starting new path (#469), starting at (108, 111). 34 paths left in queue
# starting new path (#470), starting at (107, 112). 33 paths left in queue
# starting new path (#471), starting at (108, 111). 32 paths left in queue
# starting new path (#472), starting at (107, 112). 31 paths left in queue
# starting new path (#473), starting at (108, 111). 30 paths left in queue
# starting new path (#474), starting at (107, 112). 29 paths left in queue
# starting new path (#475), starting at (108, 111). 28 paths left in queue
# starting new path (#476), starting at (107, 112). 27 paths left in queue
# starting new path (#477), starting at (108, 111). 26 paths left in queue
# starting new path (#478), starting at (107, 112). 25 paths left in queue
# starting new path (#479), starting at (108, 111). 24 paths left in queue
# starting new path (#480), starting at (107, 112). 23 paths left in queue
# starting new path (#481), starting at (108, 111). 22 paths left in queue
# starting new path (#482), starting at (107, 112). 21 paths left in queue
# starting new path (#483), starting at (108, 111). 20 paths left in queue
# starting new path (#484), starting at (107, 112). 19 paths left in queue
# starting new path (#485), starting at (108, 111). 18 paths left in queue
# starting new path (#486), starting at (107, 112). 17 paths left in queue
# starting new path (#487), starting at (108, 111). 16 paths left in queue
# starting new path (#488), starting at (107, 112). 15 paths left in queue
# starting new path (#489), starting at (108, 111). 14 paths left in queue
# starting new path (#490), starting at (107, 112). 13 paths left in queue
# starting new path (#491), starting at (108, 111). 12 paths left in queue
# starting new path (#492), starting at (107, 112). 11 paths left in queue
# starting new path (#493), starting at (108, 111). 10 paths left in queue
# starting new path (#494), starting at (107, 112). 9 paths left in queue
# starting new path (#495), starting at (108, 111). 8 paths left in queue
# starting new path (#496), starting at (107, 112). 7 paths left in queue
# starting new path (#497), starting at (108, 111). 6 paths left in queue
# starting new path (#498), starting at (107, 112). 5 paths left in queue
# starting new path (#499), starting at (108, 111). 4 paths left in queue
# starting new path (#500), starting at (107, 112). 3 paths left in queue
# starting new path (#501), starting at (108, 111). 2 paths left in queue
# starting new path (#502), starting at (107, 112). 1 paths left in queue
# starting new path (#503), starting at (108, 111). 0 paths left in queue
# found 252 paths to end
# max_path_length: 2430

# %% [markdown]
# ## part 2:

# %%
input_text2 = []
for row in input_text:
    input_text2.append(row.replace('>', '.').replace('v', '.'))

assert len(input_text2) == len(input_text)
assert len(input_text2[0]) == len(input_text[0])

unique_chars = set()
for row in input_text2:
    unique_chars.update(row)
print(f'unique_chars: {unique_chars}')
# Out:
# unique_chars: {'.', '#'}

# %%
paths_to_end = find_longest_path(input_text2, verbose=1)
paths_length = [len(path.visited_nodes) for path in paths_to_end]
max_path_length = max(paths_length)
print(f'max_path_length: {max_path_length}')
