# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import os, sys 
sys.path.append('..')
import collections
import copy
import itertools
import aoc_utils as au
import math 
from tqdm import tqdm

# %%
input_text = au.read_txt_file_lines()
n_rows = len(input_text)
n_cols = len(input_text[0])
# for ii in range(1, n_ro`ws):
#     assert len(input_text[ii]) == n_cols, f'row {ii} has {len(input_text[ii])} cols, not {n_cols}'
print(f'input has {n_rows} rows and {n_cols} cols')
# Out:
# input has 5 rows and 3780 cols

# %%
input_text[1]
# Out:
# '45 64  387 23'

# %%
rows = [r.split(' ') for r in input_text]
rows = [[c if c in '+*' else int(c) for c in r if len(c) > 0] for r in rows]

for i_r, r in enumerate(rows[1:]):
    assert len(r) == len(rows[i_r])
n_cols = len(r)

# rows

# %%
total = 0 
nums = np.array(rows[:-1])

for id, sign in enumerate(rows[-1]):
    if sign == '+':
        total += np.sum(nums[:, id])
    elif sign == '*':
        sub_total = 1
        for n in nums[:, id]:
            sub_total *= n
        total += sub_total 

total
# Out:
# np.int64(4722948564882)

# %% [markdown]
# ## part 2

# %%
## (the below code doesn't work for the toy example because of leading spaces)

## Replace shared spaces with 'x' to split columns
cols_split = [-1]
input_text = [list(r) for r in input_text]
n_rows = len(input_text)
for id in range(len(input_text[0])):
    is_split = True 
    for row in range(n_rows):
        if input_text[row][id] != ' ':
            is_split = False
            break 
    if is_split:
        for row in range(n_rows):
            input_text[row][id] = 'x'

new_rows = [''.join(r).split('x') for r in input_text]
len(new_rows)


## Rejig numbers
total = 0
for id_num in range(len(new_rows[0])):
    n_cols = len(new_rows[0][id_num])
    tmp_nums = [new_rows[r][id_num] for r in range(len(new_rows) - 1)] 
    new_nums = []
    for c in range(n_cols):
        new_nums.append(int(''.join([tmp_nums[r][c] for r in range(len(tmp_nums))])))
    if new_rows[-1][id_num][0] == '+':
        total += np.sum(new_nums)
    elif new_rows[-1][id_num][0] == '*':
        sub_total = 1
        for n in new_nums:
            sub_total *= n
        total += sub_total

total
# Out:
# np.int64(9581313737063)
